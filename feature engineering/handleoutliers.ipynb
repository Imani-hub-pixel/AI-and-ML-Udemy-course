# %%
import numpy as np

# %%
list_marks=[10,223,20,30,233,40,46,50,60,70,23,80,124,90,100]
minimum,Q1,median,Q3,maximum=np.quantile(list_marks,[0,0.25,0.5,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(10.0),
#  np.float64(35.0),
#  np.float64(60.0),
#  np.float64(95.0),
#  np.float64(233.0))

# %%
#Compute IQR
IQR=Q3-Q1
IQR
# Out:
# np.float64(60.0)

# %%
lower_fence=Q1-1.5*IQR
upper_fence=Q3+1.5*IQR
lower_fence,upper_fence
# Out:
# (np.float64(-55.0), np.float64(185.0))

# %%
list_marks=[10,223,20,30,233,40,46,50,60,70,23,80,124,90,100]

# %%
import seaborn as sns
sns.boxplot(list_marks)
# Out:
# <Axes: >
